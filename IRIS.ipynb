# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\shara\OneDrive\Desktop\ClassNotes FSDS\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")
df = df.drop(columns = 'Id', axis = 1)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
id(df)
# Out:
# 2137696870800

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.isna()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df[1:]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df.SepalLengthCm.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: SepalLengthCm, dtype: float64

# %%
df[['SepalLengthCm', 'SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df[['SepalLengthCm', 'SepalWidthCm']].head()
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %%
df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
species_un = df['Species'].unique
species_un
# Out:
# <bound method Series.unique of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object>

# %%
df['Species'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.countplot(data = df, x = 'Species')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.distplot(df['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.lmplot(data = df, x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species', fit_reg=False)

# %%
sns.lmplot(data = df, x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species', fit_reg=True)

# %%
sns.lmplot(data = df, x = 'PetalLengthCm', y = 'PetalWidthCm', hue = 'Species', fit_reg=True)

# %%
sns.lmplot(data = df, x = 'SepalLengthCm', y = 'PetalLengthCm', hue = 'Species', fit_reg=True)

# %%
sns.jointplot(data = df, x = 'SepalLengthCm', y = 'PetalLengthCm', hue = 'Species')

# %%
sns.jointplot(data = df, x = 'SepalWidthCm', y = 'SepalLengthCm', kind = 'hex')

# %%
sns.jointplot(data = df, x = 'SepalLengthCm', y = 'SepalWidthCm', kind = 'reg')

# %%
sns.jointplot(data = df, x = 'Species', y = 'PetalLengthCm')

# %%
sns.jointplot(data = df, x = 'Species', y = 'PetalWidthCm')

# %%
g = sns.catplot(x='SepalLengthCm', 
                   y='SepalWidthCm', 
                   data=df, 
                   hue='Species',  # Color by stage
                   col='Species',  # Separate by stage
                   kind='swarm') # Swarmplot

# %%
new_df = df.drop(columns='Species')
corr = new_df.corr()
sns.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
sns.pairplot(data = df, hue = 'Species',kind = 'hist')

# %%
sns.pairplot(data = df, hue = 'Species')

# %%
fig= plt.gcf()
fig.set_size_inches = (10, 6)
fig = sns.boxplot(data = df, x = 'Species', y = 'SepalLengthCm',palette= 'Set1')

# %%
df.boxplot(by = 'Species', figsize= (10, 6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
f, axs = plt.subplots(2,2, figsize = (10, 6))

sns.violinplot(data = df, x = 'Species', y = 'SepalLengthCm',ax= axs[0,0])
axs[0,0].set_title('SepalLength of Species')

sns.violinplot(data = df, x = 'Species', y = 'SepalWidthCm',ax = axs[0,1])
axs[0,1].set_title("SepalWidth of Species")

sns.violinplot(data = df, x = 'Species', y = 'PetalLengthCm',ax = axs[1,0])
axs[1,0].set_title("PetalLengthCm of Species")

sns.violinplot(data = df, x = 'Species', y = 'PetalWidthCm',ax = axs[1,1])
axs[1,1].set_title("PetalWidthCm of Species")


# plt.show()
plt.tight_layout()

# %%
se = df[df['Species'] == 'Iris-setosa']
ve = df[df['Species'] == 'Iris-versicolor']
vi = df[df['Species'] == 'Iris-virginica']

f, axs = plt.subplots(3,2, figsize = (15, 8))

sns.kdeplot(data = df, x = se['SepalLengthCm'], y = se['SepalWidthCm'], cmap ='plasma', shade = 'True', ax = axs[0,0])
axs[0,0].set_title("Setosa-sepal")
sns.kdeplot(data = df, x = se['PetalLengthCm'], y = se['PetalWidthCm'], cmap ='plasma', shade = 'True', ax = axs[0,1])
axs[0,1].set_title("setosa-petal")
sns.kdeplot(data = df, x = ve['SepalLengthCm'], y = ve['SepalWidthCm'], cmap ='plasma', shade = 'True', ax = axs[1,0])
axs[1,0].set_title("Versicolor-sepal")
sns.kdeplot(data = df, x = ve['PetalLengthCm'], y = ve['PetalWidthCm'], cmap ='plasma', shade = 'True', ax = axs[1,1])
axs[1,1].set_title("Versicolor-petal")
sns.kdeplot(data = df, x = vi['SepalLengthCm'], y = vi['SepalWidthCm'], cmap ='plasma', shade = 'True', ax = axs[2,0])
axs[2,0].set_title("virginica-sepal")
sns.kdeplot(data = df, x = vi['PetalLengthCm'], y = vi['PetalWidthCm'], cmap ='plasma', shade = 'True', ax = axs[2,1])
axs[2,1].set_title("Viginica-petal")

plt.tight_layout()

# %%
f, axs = plt.subplots(2,2, figsize = (10, 6))

sns.boxenplot(data = df, x = 'Species', y = 'SepalLengthCm',ax= axs[0,0])
axs[0,0].set_title('SepalLength of Species')

sns.boxenplot(data = df, x = 'Species', y = 'SepalWidthCm',ax = axs[0,1])
axs[0,1].set_title("SepalWidth of Species")

sns.boxenplot(data = df, x = 'Species', y = 'PetalLengthCm',ax = axs[1,0])
axs[1,0].set_title("PetalLengthCm of Species")

sns.boxenplot(data = df, x = 'Species', y = 'PetalWidthCm',ax = axs[1,1])
axs[1,1].set_title("PetalWidthCm of Species")


# plt.show()
plt.tight_layout()

# %%
f, axs = plt.subplots(2,2, figsize = (10, 6))

sns.swarmplot(data = df, x = 'Species', y = 'SepalLengthCm',ax= axs[0,0])
axs[0,0].set_title('SepalLength of Species')

sns.swarmplot(data = df, x = 'Species', y = 'SepalWidthCm',ax = axs[0,1])
axs[0,1].set_title("SepalWidth of Species")

sns.swarmplot(data = df, x = 'Species', y = 'PetalLengthCm',ax = axs[1,0])
axs[1,0].set_title("PetalLengthCm of Species")

sns.swarmplot(data = df, x = 'Species', y = 'PetalWidthCm',ax = axs[1,1])
axs[1,1].set_title("PetalWidthCm of Species")


# plt.show()
plt.tight_layout()

# %%
sns.violinplot(data = df, x = 'Species', y = 'SepalLengthCm', inner=None)
sns.swarmplot(data = df, x = 'Species', y = 'SepalLengthCm',color='k', alpha = 0.7)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.stripplot(data = df, x = 'Species', y = 'SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
g = sns.FacetGrid(data = df, hue = 'Species', height = 7)
g.map(sns.scatterplot, 'SepalLengthCm', 'SepalWidthCm')
